# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.44.19%20AM.png](attachment:Screenshot%202023-11-22%20at%208.44.19%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.44.30%20AM.png](attachment:Screenshot%202023-11-22%20at%208.44.30%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.45.29%20AM.png](attachment:Screenshot%202023-11-22%20at%208.45.29%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.45.40%20AM.png](attachment:Screenshot%202023-11-22%20at%208.45.40%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.46.02%20AM.png](attachment:Screenshot%202023-11-22%20at%208.46.02%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.46.12%20AM.png](attachment:Screenshot%202023-11-22%20at%208.46.12%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.48.14%20AM.png](attachment:Screenshot%202023-11-22%20at%208.48.14%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.48.51%20AM.png](attachment:Screenshot%202023-11-22%20at%208.48.51%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.49.01%20AM.png](attachment:Screenshot%202023-11-22%20at%208.49.01%20AM.png)

# %% [markdown]
# ----

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.49.38%20AM.png](attachment:Screenshot%202023-11-22%20at%208.49.38%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.50.02%20AM.png](attachment:Screenshot%202023-11-22%20at%208.50.02%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.50.28%20AM.png](attachment:Screenshot%202023-11-22%20at%208.50.28%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.52.26%20AM.png](attachment:Screenshot%202023-11-22%20at%208.52.26%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.53.45%20AM.png](attachment:Screenshot%202023-11-22%20at%208.53.45%20AM.png)

# %% [markdown]
# ----

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.54.09%20AM.png](attachment:Screenshot%202023-11-22%20at%208.54.09%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%208.54.41%20AM.png](attachment:Screenshot%202023-11-22%20at%208.54.41%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.04.32%20AM.png](attachment:Screenshot%202023-11-22%20at%209.04.32%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.04.52%20AM.png](attachment:Screenshot%202023-11-22%20at%209.04.52%20AM.png)

# %%
def solve(cmd, stack) :
    if cmd[0] == "push" :
        stack.append(cmd[1])
    elif cmd[0] == "pop" :
        print("Oops!" if len(stack) == 0 else stack.pop())
    elif cmd[0] == "peek" :
        print("None!" if len(stack) == 0 else stack[-1])
    elif cmd[0] == "size" :
        print(len(stack))
    elif cmd[0] == "empty" :
        print(len(stack) == 0)
        
N = int(input())
stack = []
for _ in range(N) :
    cmd = input().split()
    solve(cmd, stack)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.13.41%20AM.png](attachment:Screenshot%202023-11-22%20at%209.13.41%20AM.png)

# %% [markdown]
# ---

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.14.04%20AM.png](attachment:Screenshot%202023-11-22%20at%209.14.04%20AM.png)
