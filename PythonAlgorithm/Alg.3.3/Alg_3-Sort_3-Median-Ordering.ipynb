# %% [markdown]
# ![Screenshot%202023-10-30%20at%208.53.55%20AM.png](attachment:Screenshot%202023-10-30%20at%208.53.55%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%208.57.18%20AM.png](attachment:Screenshot%202023-10-30%20at%208.57.18%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%208.57.37%20AM.png](attachment:Screenshot%202023-10-30%20at%208.57.37%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%208.58.06%20AM.png](attachment:Screenshot%202023-10-30%20at%208.58.06%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%208.58.51%20AM.png](attachment:Screenshot%202023-10-30%20at%208.58.51%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%208.59.01%20AM.png](attachment:Screenshot%202023-10-30%20at%208.59.01%20AM.png)

# %% [markdown]
# ---

# %% [markdown]
# ![Screenshot%202023-10-30%20at%209.00.23%20AM.png](attachment:Screenshot%202023-10-30%20at%209.00.23%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%209.00.48%20AM.png](attachment:Screenshot%202023-10-30%20at%209.00.48%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%209.01.02%20AM.png](attachment:Screenshot%202023-10-30%20at%209.01.02%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%209.01.33%20AM.png](attachment:Screenshot%202023-10-30%20at%209.01.33%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%209.02.13%20AM.png](attachment:Screenshot%202023-10-30%20at%209.02.13%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%209.02.56%20AM.png](attachment:Screenshot%202023-10-30%20at%209.02.56%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%209.03.25%20AM.png](attachment:Screenshot%202023-10-30%20at%209.03.25%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%209.04.17%20AM.png](attachment:Screenshot%202023-10-30%20at%209.04.17%20AM.png)

# %% [markdown]
# ---

# %% [markdown]
# ![Screenshot%202023-10-30%20at%209.06.55%20AM.png](attachment:Screenshot%202023-10-30%20at%209.06.55%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%209.09.33%20AM.png](attachment:Screenshot%202023-10-30%20at%209.09.33%20AM.png)

# %%
def solve(s) :
    s.sort()
    while len(s) > 0 :
        mid = (len(s)-1)//2
        print(s[mid], end=" ")
        s.remove(s[mid])
    print()
N = int(input())
S = list(map(int, input().split()))

# %%
def solve(n, s) :
    s.sort()
    while len(s) > 0 :
        mid = (len(s)-1)//2
        # print(s[mid], end=" ")
        print(s, mid, s[mid])
        s.remove(s[mid])
    print()

N = int(input())
S = list(map(int, input().split()))
solve(N, S)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%209.23.29%20AM.png](attachment:Screenshot%202023-10-30%20at%209.23.29%20AM.png)

# %% [markdown]
# ---

# %% [markdown]
# ![Screenshot%202023-10-30%20at%209.25.06%20AM.png](attachment:Screenshot%202023-10-30%20at%209.25.06%20AM.png)
