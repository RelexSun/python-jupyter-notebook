# %% [markdown]
# ![Screenshot 2023-11-29 at 11.04.19 in the morning.png](attachment:3468414b-d5b0-4879-b768-4343ef8c8b54.png)

# %% [markdown]
# ![Screenshot 2023-11-29 at 11.04.55 in the morning.png](attachment:bd549834-77d8-4c2c-9f75-beb862f78aef.png)

# %% [markdown]
# ![Screenshot 2023-11-29 at 11.05.17 in the morning.png](attachment:bdb2b87f-da0b-49c8-be7e-de44665a7fa1.png)

# %% [markdown]
# ![Screenshot 2023-11-29 at 11.05.29 in the morning.png](attachment:5e2c9c92-ab39-44f5-a0d4-8adcaf663044.png)

# %% [markdown]
# ![Screenshot 2023-11-29 at 11.05.42 in the morning.png](attachment:5c3f2c29-f2ec-460e-871a-3eca6ba4c4dc.png)

# %% [markdown]
# ![Screenshot 2023-11-29 at 11.05.53 in the morning.png](attachment:8dfe366a-ba81-4a10-b413-be42b27ca267.png)

# %% [markdown]
# ----

# %% [markdown]
# ![Screenshot 2023-11-29 at 11.06.57 in the morning.png](attachment:6be9cbaa-0962-4521-baee-7937a85673d3.png)

# %% [markdown]
# ![Screenshot 2023-11-29 at 11.07.20 in the morning.png](attachment:1bebe530-cc5f-4298-bf6a-fe2c5aebc5fb.png)

# %% [markdown]
# <strong>Therefore, to efficiently solve this problem, we can use min-heap and max-heap, and maintain the same size for both heaps.</strong>

# %% [markdown]
# ![Screenshot 2023-11-29 at 11.09.05 in the morning.png](attachment:669523c0-36f1-4543-94ad-76adb2b563c5.png)

# %% [markdown]
# - By adding data to these two heaps in this way:
#     - The sizes of the max-heap and min-heap will either be equal, or
#     - The max-heap's length will be one greater than the min-heap's length.
#
# <strong>Therefore, the maximum value in the max-heap always becomes the median.</strong>

# %% [markdown]
# ![Screenshot 2023-11-29 at 11.29.55 in the morning.png](attachment:d57b8412-6fa9-4018-8f64-e5a4b2a2001f.png)

# %% [markdown]
# ---

# %% [markdown]
# ![Screenshot 2023-11-29 at 11.30.21 in the morning.png](attachment:c548298d-cbda-4a1d-a2a6-c893868f9899.png)

# %% [markdown]
# ![Screenshot 2023-11-29 at 11.31.00 in the morning.png](attachment:3008d91d-5d1e-4cf8-a301-25df6f3b891b.png)

# %% [markdown]
# ![Screenshot 2023-11-29 at 11.31.44 in the morning.png](attachment:db05f5fb-2049-47c5-af8a-207e6ba04dd6.png)

# %%
from heapq import heappush, heappop

def solve(A) :
    maxheap, minheap = [], []
    for a in A :
        heappush(maxheap, -a)
        heappush(minheap, -heappop(maxheap))
        if len(maxheap) < len(minheap) :
            heappush(maxheap, -heappop(minheap))
        print(-maxheap[0], end=" ")
    print()
A = list(map(int, input().split()))
solve(A)

# %% [markdown]
# ![Screenshot 2023-11-29 at 11.35.13 in the morning.png](attachment:b53e3bb0-5dfd-4f9c-bac9-2b65674367de.png)

# %% [markdown]
# ---

# %% [markdown]
# ![Screenshot 2023-11-29 at 11.35.49 in the morning.png](attachment:2667df3e-e055-436d-a1ff-220662aa4fda.png)
