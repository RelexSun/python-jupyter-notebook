# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.12.48%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.12.48%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.12.59%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.12.59%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.24.36%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.24.36%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.24.48%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.24.48%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.25.17%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.25.17%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.25.23%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.25.23%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.25.35%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.25.35%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.25.45%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.25.45%20AM.png)

# %% [markdown]
# ----

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.26.23%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.26.23%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.27.03%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.27.03%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.27.09%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.27.09%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.30.58%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.30.58%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.31.09%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.31.09%20AM.png)

# %% [markdown]
# ---

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.31.37%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.31.37%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.32.06%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.32.06%20AM.png)

# %%
def solve(cmd, queue) :
    if cmd[0] == 'enqueue' :
        queue.append(cmd[1])
    elif cmd[0] == 'dequeue' :
        print('Oops!' if len(queue) == 0 else queue.pop(0))
    elif cmd[0] == 'peek' :
        print("None!" if len(queue) == 0 else queue[0])
    elif cmd[0] == 'size' :
        print(len(queue))
    elif cmd[0] == 'empty' :
        print(len(queue) == 0)
        
# Accept the number of commands as an int input
N = int(input()) 

# Initialize the queue as an empty list since we need to use it with queue operations.
queue = []

# The sovle function receives cmd and the queue to solve the respective problem, 
# so it takes cmd as input for the number of commands
for _ in range(N) :
    cmd = input().split() # The input string is divided using the 'split' and assigned to cmd.
    solve(cmd, queue)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2012.15.22%20PM.png](attachment:Screenshot%202023-11-25%20at%2012.15.22%20PM.png)

# %%
def solve(cmd, queue) :

    if cmd[0] == 'enqueue' :
        queue.enqueue(cmd[1])
    elif cmd[0] == 'dequeue' :
        print('Oops!' if len(queue) == 0 else queue.dequeue())
    elif cmd[0] == 'peek' :
        print("None!" if len(queue) == 0 else queue.peek())
    elif cmd[0] == 'size' :
        print(queue.size())
    elif cmd[0] == 'empty' :
        print(queue.empty())
        
from queue import Queue
        
N = int(input())
queue = Queue()
for _ in range(N) :
    cmd = input().split()
    solve(cmd, queue)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%202.05.50%20PM.png](attachment:Screenshot%202023-11-25%20at%202.05.50%20PM.png)

# %% [markdown]
# ----

# %% [markdown]
# ![Screenshot%202023-11-25%20at%202.06.22%20PM.png](attachment:Screenshot%202023-11-25%20at%202.06.22%20PM.png)
