# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.15.45%20AM.png](attachment:Screenshot%202023-11-22%20at%209.15.45%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.15.54%20AM.png](attachment:Screenshot%202023-11-22%20at%209.15.54%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.16.11%20AM.png](attachment:Screenshot%202023-11-22%20at%209.16.11%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.16.48%20AM.png](attachment:Screenshot%202023-11-22%20at%209.16.48%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.16.55%20AM.png](attachment:Screenshot%202023-11-22%20at%209.16.55%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.17.20%20AM.png](attachment:Screenshot%202023-11-22%20at%209.17.20%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.18.54%20AM.png](attachment:Screenshot%202023-11-22%20at%209.18.54%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.19.04%20AM.png](attachment:Screenshot%202023-11-22%20at%209.19.04%20AM.png)

# %% [markdown]
# ---

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.19.57%20AM.png](attachment:Screenshot%202023-11-22%20at%209.19.57%20AM.png)

# %% [markdown]
# # Stack Visualization

# %% [markdown]
# ![stack.webp](attachment:stack.webp)

# %% [markdown]
# ![stack-operations.webp](attachment:stack-operations.webp)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.30.18%20AM.png](attachment:Screenshot%202023-11-22%20at%209.30.18%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.41.09%20AM.png](attachment:Screenshot%202023-11-22%20at%209.41.09%20AM.png)

# %% [markdown]
# ---

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.41.46%20AM.png](attachment:Screenshot%202023-11-22%20at%209.41.46%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-22%20at%209.42.35%20AM.png](attachment:Screenshot%202023-11-22%20at%209.42.35%20AM.png)

# %%
from stack import Stack

def solve(n, s) :
    stack = Stack()
    for i in range(n) :
        while not stack.empty() and s[i] >= stack.peek() :
            stack.pop()
        stack.push(s[i])
    print(stack.stack)
    return stack.size()

N = int(input())
S = list(map(int, input().split()))
print(solve(N, S))
# Out:
# 10
# 7 9 10 6 5 8 4 2 1 3
# [10, 8, 4, 3]
# 4

# %%
def solve2(n, s) :
    stack = []
    for i in range(n) :
        while len(stack) > 0 and s[i] >= stack[-1] :
            stack.pop()
        stack.append(s[i])
    return len(stack)

N = int(input())
S = list(map(int, input().split()))
print(solve2(N, S))
# Out:
# 5
# 5 4 3 2 1
# 5

# %% [markdown]
# ![Screenshot%202023-11-22%20at%2010.27.26%20AM.png](attachment:Screenshot%202023-11-22%20at%2010.27.26%20AM.png)

# %% [markdown]
# ----

# %% [markdown]
# ![Screenshot%202023-11-22%20at%2010.28.22%20AM.png](attachment:Screenshot%202023-11-22%20at%2010.28.22%20AM.png)
