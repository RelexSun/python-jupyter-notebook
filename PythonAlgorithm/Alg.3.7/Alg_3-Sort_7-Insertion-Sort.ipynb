# %% [markdown]
# ![Screenshot%202023-10-30%20at%2011.59.32%20AM.png](attachment:Screenshot%202023-10-30%20at%2011.59.32%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%2011.59.43%20AM.png](attachment:Screenshot%202023-10-30%20at%2011.59.43%20AM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%2012.00.07%20PM.png](attachment:Screenshot%202023-10-30%20at%2012.00.07%20PM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%2012.00.58%20PM.png](attachment:Screenshot%202023-10-30%20at%2012.00.58%20PM.png)

# %% [markdown]
# ![Screenshot%202023-10-30%20at%2012.01.08%20PM.png](attachment:Screenshot%202023-10-30%20at%2012.01.08%20PM.png)

# %% [markdown]
# ---

# %% [markdown]
# ![Screenshot%202023-11-02%20at%208.52.26%20AM.png](attachment:Screenshot%202023-11-02%20at%208.52.26%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%208.53.08%20AM.png](attachment:Screenshot%202023-11-02%20at%208.53.08%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%209.00.14%20AM.png](attachment:Screenshot%202023-11-02%20at%209.00.14%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%209.06.54%20AM.png](attachment:Screenshot%202023-11-02%20at%209.06.54%20AM.png)

# %% [markdown]
# ---

# %% [markdown]
# ![Screenshot%202023-11-02%20at%209.10.42%20AM.png](attachment:Screenshot%202023-11-02%20at%209.10.42%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%209.10.50%20AM.png](attachment:Screenshot%202023-11-02%20at%209.10.50%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%209.12.20%20AM.png](attachment:Screenshot%202023-11-02%20at%209.12.20%20AM.png)

# %%
def insertionsort(n, s) :
    cnt = 0
    for i in range(1, n) :
        j, val = i - 1, s[i]
        cnt += 1
        while j >= 0 and s[j] > val :
            s[j + 1] = s[j]
            j -= 1
            cnt += 1
        s[j + 1] = val
    return cnt

N = int(input())
S = list(map(int, input().split()))
print(insertionsort(N, S))

# %% [markdown]
# ![Screenshot%202023-11-02%20at%209.34.55%20AM.png](attachment:Screenshot%202023-11-02%20at%209.34.55%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%209.35.47%20AM.png](attachment:Screenshot%202023-11-02%20at%209.35.47%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%209.36.01%20AM.png](attachment:Screenshot%202023-11-02%20at%209.36.01%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%209.36.21%20AM.png](attachment:Screenshot%202023-11-02%20at%209.36.21%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%209.36.48%20AM.png](attachment:Screenshot%202023-11-02%20at%209.36.48%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-02%20at%209.36.56%20AM.png](attachment:Screenshot%202023-11-02%20at%209.36.56%20AM.png)

# %% [markdown]
# ----

# %% [markdown]
# ![Screenshot%202023-11-08%20at%208.31.44%20AM.png](attachment:Screenshot%202023-11-08%20at%208.31.44%20AM.png)
