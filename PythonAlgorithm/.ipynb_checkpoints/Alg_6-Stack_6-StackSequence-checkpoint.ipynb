# %% [markdown]
# ![Screenshot%202023-11-25%20at%2010.26.36%20AM.png](attachment:Screenshot%202023-11-25%20at%2010.26.36%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2010.28.02%20AM.png](attachment:Screenshot%202023-11-25%20at%2010.28.02%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2010.32.05%20AM.png](attachment:Screenshot%202023-11-25%20at%2010.32.05%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2010.32.47%20AM.png](attachment:Screenshot%202023-11-25%20at%2010.32.47%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2010.33.28%20AM.png](attachment:Screenshot%202023-11-25%20at%2010.33.28%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2010.33.40%20AM.png](attachment:Screenshot%202023-11-25%20at%2010.33.40%20AM.png)

# %% [markdown]
# ----

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2010.39.33%20AM.png](attachment:Screenshot%202023-11-25%20at%2010.39.33%20AM.png)

# %% [markdown]
# # Expample of Stack Sequence in video

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2010.49.16%20AM.png](attachment:Screenshot%202023-11-25%20at%2010.49.16%20AM.png)

# %% [markdown]
# ----

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2010.50.22%20AM.png](attachment:Screenshot%202023-11-25%20at%2010.50.22%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2010.50.59%20AM.png](attachment:Screenshot%202023-11-25%20at%2010.50.59%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.00.56%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.00.56%20AM.png)

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.01.24%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.01.24%20AM.png)

# %%
def solve(n, s) :
    stack, operation = [], ""
    j = 0
    for i in range(1, n + 1) :
        stack.append(i)
        operation += '+'
        while stack and s[j] == stack[-1] :
            stack.pop()
            operation += '-'
            j += 1
    return "No" if stack else operation

N = int(input())
S = list(map(int, input().split()))
print(solve(N, S))

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.09.45%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.09.45%20AM.png)

# %% [markdown]
# ----

# %% [markdown]
# ![Screenshot%202023-11-25%20at%2011.10.26%20AM.png](attachment:Screenshot%202023-11-25%20at%2011.10.26%20AM.png)
